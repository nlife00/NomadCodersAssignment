# %%
import openai, json

client = openai.OpenAI()
messages = []

# %%
def process_ai():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
    )

    res_message = response.choices[0].message.content
    messages.append({"role": "assistant", "content": res_message})
    print(f"LLM : {res_message}")

# %%
while True:
    message = input("User Input")
    if message == "quit":
        break
    else:
        messages.append({"role": "user", "content": message})
        print(f"User : {message}")
        process_ai()
# Out:
# User : 안녕. 난 먹고라고 해. 영화를 추천받으려고 하는데 난 액션 영화를 주로 봐.
# LLM : 안녕하세요, 먹고! 액션 영화를 좋아하신다니 좋은 선택이네요. 추천할 만한 액션 영화 몇 편을 소개해드릴게요.
#
# 1. **존 윅 (John Wick)** - 키아누 리브스가 주연한 이 영화는 복수를 위해 돌아온 전직 킬러의 이야기입니다. 뛰어난 액션과 스타일리시한 연출이 특징입니다.
#
# 2. **매드 맥스: 분노의 도로 (Mad Max: Fury Road)** - 포스트 아포칼립스 세계에서의 스릴 넘치는 추적전을 다룬 이 영화는 시각적으로도 압도적이며 액션이 가득합니다.
#
# 3. **다크 나이트 (The Dark Knight)** - 크리스토퍼 놀란 감독의 배트맨 시리즈 중 두 번째 작품으로, 조커가 등장해 긴장감 넘치는 이야기를 만들어냅니다.
#
# 4. **미션 임파서블: 폴 아울트 (Mission: Impossible – Fallout)** - 톰 크루즈가 주연한 이 영화는 스펙타클한 액션과 긴박한 스토리로 사랑받고 있습니다.
#
# 5. **로그 원: 스타워즈 스토리 (Rogue One: A Star Wars Story)** - 스타워즈의 스핀오프 작품으로, 전투와 액션이 훌륭하게 어우러진 이야기를 담고 있습니다.
#
# 이 영화들은 모두 액션 장르에서 뛰어난 작품들이니, 한 번 감상해보세요! 어떤 영화가 제일 끌리시나요?
# User : 존윅, 다크나이트, 미션 임파서블은 이미 모두 봤어. 모두 재미있게 봤지. 되도록 최신 영화중에 오늘 볼만한 것을 추천해줘
# LLM : 좋아요! 최근 개봉한 액션 영화 중에서 추천할 만한 작품을 몇 편 소개해드릴게요.
#
# 1. **존 윅 4 (John Wick: Chapter 4)** (2023) - 키아누 리브스가 다시 한번 돌아온 액션 시리즈로, 더욱 강력한 적들과 맞서 싸우는 존 윅의 이야기를 다룹니다. 시리즈 최고의 액션과 스토리가 기대됩니다.
#
# 2. **퀴원 (QnA)** (2023) - 러시아에서 온 요원이 범죄 조직에 대항해 싸우는 현대적인 액션 스릴러입니다. 짜릿한 액션과 긴장감 넘치는 전개가 매력적입니다.
#
# 3. **탈론 (Talon)** (2023) - 다양한 국제 작전과 스릴 넘치는 액션이 가득한 영화로, 강력한 캐릭터들이 주요 범죄 조직과 맞서는 이야기를 담고 있습니다.
#
# 4. **분노의 질주: 라이브 투 어라이즈 (Fast X)** (2023) - 분노의 질주 시리즈의 최신작으로, 화려한 카 체이싱과 액션이 가득한 작품입니다. 드웨인 존슨과 제이슨 모모아가 등장해 더욱 흥미진진한 이야기를 만들어냅니다.
#
# 이 중에서 한 편 고르시면 좋을 것 같아요! 오늘 즐거운 영화 관람 되세요!
# User : 내가 봤던게 뭐라고 했지?
# LLM : 먹고님이 이전에 본 액션 영화로는 "존 윅," "다크 나이트," 그리고 "미션 임파서블"을 말씀하셨습니다. 이 세 편 모두 재미있게 보셨다고 하셨죠. 추가로 추천이 필요하시면 말씀해 주세요!
